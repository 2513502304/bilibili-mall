# %%
import pandas as pd
import orjson

save_path = "./Data/bmall_all_data.json"

with open(save_path, "rb") as f:
    content = f.read()
    all_data = orjson.loads(content)

df = pd.DataFrame(all_data)

# f"https://mall.bilibili.com/neul-next/index.html?page=magic-market_detail&noTitleBar=1&itemsId={c2cItemsId}&from=market_index"
df["c2cItemsLink"] = df["c2cItemsId"].apply(
    lambda x: f"https://mall.bilibili.com/neul-next/index.html?page=magic-market_detail&noTitleBar=1&itemsId={x}&from=market_index"
)

# %%
search: pd.DataFrame = df[df["c2cItemsName"].str.contains("GSC 超天酱")][
    df["totalItemsCount"] == 1
].drop_duplicates(
    subset=["c2cItemsName"],
    keep="last",
)
search
# Out:
# /var/folders/hf/4h0z7p353bg25yn52mfwj8y80000gn/T/ipykernel_43670/2154786770.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   search: pd.DataFrame = df[df["c2cItemsName"].str.contains("GSC 超天酱")][
#          c2cItemsId  type                        c2cItemsName  \
# 3839   179960083133     1    GSC 超天酱Anniversary Party Ver. 手办
# 3980   181392616012     1  GSC 超天酱Anniversary Party Ver. 正比手办
# 8644   181708666832     1                        GSC 超天酱 可动手办
# 15678  181018087879     1     GSC 超天酱INTERNET YAMERO Ver.  手办
# 15947  181630618566     1      GSC 超天酱INTERNET YAMERO Ver. 手办
# 16160  181719151903     1   GSC 超天酱INTERNET YAMERO Ver.  正比手办
#
#                                            detailDtoList  totalItemsCount  \
# 3839   [{'blindBoxId': 226059340, 'itemsId': 12539656...                1
# 3980   [{'blindBoxId': 226713855, 'itemsId': 12539656...                1
# 8644   [{'blindBoxId': 228989715, 'itemsId': 12671643...                1
# 15678  [{'blindBoxId': 233767695, 'itemsId': 11069615...                1
# 15947  [{'blindBoxId': 221161973, 'itemsId': 11069615...                1
# 16160  [{'blindBoxId': 235760367, 'itemsId': 11069615...                1
#
#        price showPrice showMarketPrice     uid  paymentTime  isMyPublish  \
# 3839   78000       780            1059  16***2            0        False
# 3980   76000       760            1059  68***6            0        False
# 8644   41400       414             539  47***2            0        False
# 15678  17900       179             225  13***3            0        False
# 15947  17000       170             225  35***6            0        False
# 16160  16800       168             235  45***4            0        False
#
#       uspaceJumpUrl uname                                              uface  \
# 3839           None  吹***  https://i0.hdslb.com/bfs/face/6a96e4a048cc829c...
# 3980           None  成***  https://i1.hdslb.com/bfs/face/02cbd6a9d79de9c0...
# 8644           None  啫***  https://i2.hdslb.com/bfs/face/3d33dd4ac25f5067...
# 15678          None  清***  https://i0.hdslb.com/bfs/face/901435ef227c679e...
# 15947          None  叁***  https://i2.hdslb.com/bfs/face/50eef7bf7f99b819...
# 16160          None  可***  https://i2.hdslb.com/bfs/face/b5aa5d6f182657b0...
#
#                                             c2cItemsLink
# 3839   https://mall.bilibili.com/neul-next/index.html...
# 3980   https://mall.bilibili.com/neul-next/index.html...
# 8644   https://mall.bilibili.com/neul-next/index.html...
# 15678  https://mall.bilibili.com/neul-next/index.html...
# 15947  https://mall.bilibili.com/neul-next/index.html...
# 16160  https://mall.bilibili.com/neul-next/index.html...
